# %% [markdown]
# <a href="https://colab.research.google.com/github/Chieh-YuHung-hub/HTM737/blob/main/Week_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Today we learned 2 libraries of Python. Pandas and some concepts of SciKit-Learn. (SK-Learn)
#In Python, everything we type into uppercase or lowercase represent to different items.
#We compared the differences between SQL and Pandas.Both of them are for data cleaning.
#We tried several syntax in Pandas which are similar to SQL.
#SciKit Learn is for building models.
#One-hot encoding: Converting categorical variable into binary variables (Boolean values is a kind of binary variables, but only for T/F?)
#Scaling and Centering = Standardization: adjust values to make it has a mean of zero and standard deviation of 1
#The purpose to do standardization is to prevent variables with larger ranges from being overrepresented
#Binarization: Similar concept to One-hot encoding, but Binarization needs a threshold
#Mean imputation: Filling in missing values with the average
#Zero imputation: Filling in missing values with Zero
#We review the concepts of feature selection, model building and evaluation
#Other libraries:
#PySpark: use it when dealing with big data
#NumPy: High-performance numerical, matrix, and vector computing.
#Matplotlib: Data Visualization

# %%
My_List = [1, 'a'] #Define a list called My_List

# %%
print(My_List)
# Out:
# [1, 'a']

# %%
import pandas as pd #Import"pandas"(the library)

# %%
my_first_df = pd.DataFrame(My_List) #Build a dataframe(means a table with data)"DataFrame"" and store the list"My_List" as Pandas data frame.
#pd.DataFrame means calling the function DataFrame from the pd library (which is Pandas).

# %%
from pandas import DataFrame #The function "from" is similar to "SELECT" in SQL. Then, import the dataframe.
#"from" means pick "function" from which library.
#"SELECT...FROM.."means pick data from a specific table and specific column.

# %%
my_first_df = DataFrame(My_List)
#As we've imported DataFrame in "pandas" library, we don't need to edit "pd.DataFrame(My_List)"

# %%
import pandas as pd
from datetime import datetime #from (a module called datetime) import (a class called datetime)

# PATIENT table
patient_data = [
    ['1', 'John', 'A', 'Smith', '1952-01-01', '1206 Fox Hollow Rd.', 'Pittsburgh', 'PA', '15213', '6789871234', 'M'],
    ['2', 'Candice', 'P', 'Jones', '1978-02-03', '1429 Orlyn Dr.', 'Los Angeles', 'CA', '90024', '3107381419', 'F'],
    ['3', 'Regina', 'H', 'Wilson', '1985-04-23', '765 Chestnut Ln.', 'Albany', 'NY', '12065', '5184590206', 'F'],
    ['4', 'Harold', '', 'Lee', '1966-11-15', '2928 Policy St.', 'Providence', 'RI', '02912', '6593482691', 'M'],
    ['5', 'Stan', 'P', 'Davis', '1958-12-30', '4271 12th St.', 'Atlanta', 'GA', '30339', '4049814933', 'M']
] #list of lists
PATIENT = pd.DataFrame(patient_data, columns=['Pid', 'Fname', 'Minit', 'Lname', 'Bdate', 'Street', 'City', 'State', 'Zip', 'Phone', 'Sex'])
#():function call
PATIENT['Bdate'] = pd.to_datetime(PATIENT['Bdate']) #Transfer the string to date

# VISIT table
visit_data = [
    ['1', '10001', '2016-01-09', 'JOHNSON', 'I50.9', 'Heart failure, unspecified', 'I10', 'Essential (primary) hypertension'],
    ['1', '10002', '2016-01-17', 'JOHNSON', 'I50.9', 'Heart failure, unspecified', 'I10', 'Essential (primary) hypertension'],
    ['2', '10003', '2016-01-15', 'WU', 'I20.9', 'Angina pectoris, unspecified', 'E11.9', 'Type 2 diabetes mellitus without complications'],
    ['3', '10004', '2016-02-01', 'JOHNSON', 'I10', 'Essential (primary) hypertension', '', ''],
    ['4', '10005', '2016-02-27', 'WU', 'I27.0', 'Primary pulmonary hypertension', 'I50.9', 'Heart failure, unspecified'],
    ['5', '10006', '2016-03-01', 'WU', 'I50.9', 'Heart failure, unspecified', 'E11.9', 'Type 2 diabetes mellitus without complications']
]
VISIT = pd.DataFrame(visit_data, columns=['Pid', 'Visit_id', 'Visit_date', 'Attending_md', 'Pri_dx_icd', 'Pri_dx_name', 'Sec_dx_icd', 'Sec_dx_name'])
VISIT['Visit_date'] = pd.to_datetime(VISIT['Visit_date'])

# MEDICATIONS table
medications_data = [
    ['1', 'LISINOPRIL', '5 mg', 'bid', 'po', 'JOHNSON', '01/09/2016', '68180-513-01'],
    ['1', 'FUROSEMIDE', '20 mg', 'bid', 'po', 'JOHNSON', '01/09/2016', '50742-104-01'],
    ['2', 'NITROGLYCERIN', '0.4 mg', 'tid', 'sl', 'WU', '01/15/2016', '59762-3304-1'],
    ['2', 'METFORMIN', '500 mg', 'bid', 'po', 'WU', '01/15/2016', '65162-175-10'],
    ['2', 'ASPIRIN', '81 mg', 'qdaily', 'po', 'WU', '01/15/2016', '63981-563-51'],
    ['2', 'METOPROLOL TARTRATE', '25 mg', 'bid', 'po', 'WU', '01/15/2016', '62332-112-31'],
    ['3', 'VALSARTAN HCTZ', '160/12.5 mg', 'qdaily', 'po', 'JOHNSON', '02/01/2016', '51655-950-52'],
    ['4', 'DILTIAZEM HYDROCHOLORIDE', '300 mg', 'qdaily', 'po', 'WU', '02/27/2016', '52544-693-19'],
    ['4', 'LISINOPRIL', '10 mg', 'bid', 'po', 'WU', '02/27/2016', '68180-514-01'],
    ['4', 'FUROSEMIDE', '40 mg', 'bid', 'po', 'WU', '02/27/2016', '68788-1966-1'],
    ['5', 'LISINOPRIL', '5 mg', 'bid', 'po', 'WU', '03/01/2016', '68180-513-01'],
    ['5', 'FUROSEMIDE', '20 mg', 'bid', 'po', 'WU', '03/01/2016', '50742-104-01'],
    ['5', 'METFORMIN', '500 mg', 'bid', 'po', 'WU', '03/01/2016', '65162-175-10']
]
MEDICATIONS = pd.DataFrame(medications_data, columns=['Pid', 'Rx_name', 'Rx_dose', 'Rx_freq', 'Rx_route', 'Prescribing_md', 'Rx_date', 'Rx_ndc'])
MEDICATIONS['Rx_date'] = pd.to_datetime(MEDICATIONS['Rx_date'])

# LABS table
labs_data = [
    ['1', 'Natriuretic peptide B', 'BNP', '42637-9', '350', 'JOHNSON', '2016-01-09'],
    ['2', 'Natriuretic peptide B', 'BNP', '42637-9', '100', 'WU', '2016-01-15'],
    ['2', 'Glucose', 'GLU', '2345-7', '225', 'WU', '2016-01-15'],
    ['2', 'Troponin I', 'TROP', '10839-9', '<0.004', 'WU', '2016-01-15'],
    ['4', 'Natriuretic peptide B', 'BNP', '42637-9', '1000', 'WU', '2016-02-27'],
    ['5', 'Natriuretic peptide B', 'BNP', '42637-9', '400', 'WU', '2016-03-01'],
    ['5', 'Glucose', 'GLU', '2345-7', '318', 'WU', '2016-03-01']
]
LABS = pd.DataFrame(labs_data, columns=['Pid', 'Lab_name', 'Lab_abbrev', 'Lab_loinc', 'Lab_value', 'Ordering_md', 'Lab_date'])
LABS['Lab_date'] = pd.to_datetime(LABS['Lab_date'])

# VITALS table
vitals_data = [
    ['1', '10001', 70, 188.4, 98.6, 95, 18, 154, 94, 97],
    ['1', '10002', 70, 188.4, 99.1, 85, 17, 157, 96, 100],
    ['2', '10003', 63, 130.2, 98.7, 82, 16, 120, 81, 100],
    ['3', '10004', 65, 120.0, None, 100, 19, 161, 100, 98],
    ['4', '10005', 66, 211.4, 98.2, 95, 19, 143, 84, 93],
    ['5', '10006', 69, 150.0, 97.6, 77, 18, 130, 86, 99]
]
VITALS = pd.DataFrame(vitals_data, columns=['Pid', 'Visit_id', 'Height_in', 'Weight_lb', 'Temp_f', 'Pulse', 'Resp_rate', 'Bp_syst', 'Bp_diast', 'SpO2'])

# MORT table
mort_data = [
    ['1', '2016-05-15'],
    ['4', '2016-06-08']
]
MORT = pd.DataFrame(mort_data, columns=['Pid', 'Mortality_date'])
MORT['Mortality_date'] = pd.to_datetime(MORT['Mortality_date'])

# Display sample data
print(PATIENT)
# Out:
#   Pid    Fname Minit   Lname      Bdate               Street         City  \
# 0   1     John     A   Smith 1952-01-01  1206 Fox Hollow Rd.   Pittsburgh
# 1   2  Candice     P   Jones 1978-02-03       1429 Orlyn Dr.  Los Angeles
# 2   3   Regina     H  Wilson 1985-04-23     765 Chestnut Ln.       Albany
# 3   4   Harold           Lee 1966-11-15      2928 Policy St.   Providence
# 4   5     Stan     P   Davis 1958-12-30        4271 12th St.      Atlanta
#
#   State    Zip       Phone Sex
# 0    PA  15213  6789871234   M
# 1    CA  90024  3107381419   F
# 2    NY  12065  5184590206   F
# 3    RI  02912  6593482691   M
# 4    GA  30339  4049814933   M

# %%
PATIENT
#It's the same as print(PATIENT)
# Out:
#   Pid    Fname Minit   Lname      Bdate               Street         City  \
# 0   1     John     A   Smith 1952-01-01  1206 Fox Hollow Rd.   Pittsburgh
# 1   2  Candice     P   Jones 1978-02-03       1429 Orlyn Dr.  Los Angeles
# 2   3   Regina     H  Wilson 1985-04-23     765 Chestnut Ln.       Albany
# 3   4   Harold           Lee 1966-11-15      2928 Policy St.   Providence
# 4   5     Stan     P   Davis 1958-12-30        4271 12th St.      Atlanta
#
#   State    Zip       Phone Sex
# 0    PA  15213  6789871234   M
# 1    CA  90024  3107381419   F
# 2    NY  12065  5184590206   F
# 3    RI  02912  6593482691   M
# 4    GA  30339  4049814933   M

# %%
PATIENT.tail(1)
#It shows the last one. If we want to see the first one, we edit: PATIENT.head(1)
#If we edit: PATIENT.head(-1), we will see everything except for the last one.
# Out:
#   Pid Fname Minit  Lname      Bdate         Street     City State    Zip  \
# 4   5  Stan     P  Davis 1958-12-30  4271 12th St.  Atlanta    GA  30339
#
#         Phone Sex
# 4  4049814933   M

# %%
PATIENT[['Pid','Fname']].head(3) #We can see the first 3 patiens' IDs and names.
# Out:
#   Pid    Fname
# 0   1     John
# 1   2  Candice
# 2   3   Regina

# %%
PATIENT[PATIENT['State']=='RI']
#PATIENT['State']=='RI' is to check if the cells of State meets the answer "RI"
#PATIENT[PATIENT['State']=='RI'] is to select the ones meets the answer "RI"
# Out:
#   Pid   Fname Minit Lname      Bdate           Street        City State  \
# 3   4  Harold         Lee 1966-11-15  2928 Policy St.  Providence    RI
#
#      Zip       Phone Sex
# 3  02912  6593482691   M

# %%
PATIENT.shape
#Show the number of rows and columns respectively.
# Out:
# (5, 11)

# %%
PATIENT.shape[0]
#Show the number of rows as its the "0"th position
# Out:
# 5

# %%
PATIENT.shape[1]
#Show the number of columns as its the 1st position
# Out:
# 11

# %%
PATIENT['Pid'].size
#The number of the cells belong to Pid (rows*columns)=5*1=5
# Out:
# 5

# %%
len(PATIENT)
#The number of rows
# Out:
# 5

# %%
new_df_inner = pd.merge(PATIENT, MORT, on='Pid', how = 'inner')
#Use "Pid" as the key to combine the table "PATIENT" and the table "MORT" with the data shown in both tables
#Similar to "INNER JOIN" in SQL

# %%
new_df_inner
# Out:
#   Pid   Fname Minit  Lname      Bdate               Street        City State  \
# 0   1    John     A  Smith 1952-01-01  1206 Fox Hollow Rd.  Pittsburgh    PA
# 1   4  Harold          Lee 1966-11-15      2928 Policy St.  Providence    RI
#
#      Zip       Phone Sex Mortality_date
# 0  15213  6789871234   M     2016-05-15
# 1  02912  6593482691   M     2016-06-08

# %%
new_df_left = pd.merge(PATIENT, MORT, on='Pid', how = 'left')
#Use "Pid" as the key to combine the table "PATIENT" and the table "MORT" based on the key data of the left table(PATIENT)
#Similar to "LEFT JOIN" in SQL

# %%
new_df_left
# Out:
#   Pid    Fname Minit   Lname      Bdate               Street         City  \
# 0   1     John     A   Smith 1952-01-01  1206 Fox Hollow Rd.   Pittsburgh
# 1   2  Candice     P   Jones 1978-02-03       1429 Orlyn Dr.  Los Angeles
# 2   3   Regina     H  Wilson 1985-04-23     765 Chestnut Ln.       Albany
# 3   4   Harold           Lee 1966-11-15      2928 Policy St.   Providence
# 4   5     Stan     P   Davis 1958-12-30        4271 12th St.      Atlanta
#
#   State    Zip       Phone Sex Mortality_date
# 0    PA  15213  6789871234   M     2016-05-15
# 1    CA  90024  3107381419   F            NaT
# 2    NY  12065  5184590206   F            NaT
# 3    RI  02912  6593482691   M     2016-06-08
# 4    GA  30339  4049814933   M            NaT

# %%
VISIT
# Out:
#   Pid Visit_id Visit_date Attending_md Pri_dx_icd  \
# 0   1    10001 2016-01-09      JOHNSON      I50.9
# 1   1    10002 2016-01-17      JOHNSON      I50.9
# 2   2    10003 2016-01-15           WU      I20.9
# 3   3    10004 2016-02-01      JOHNSON        I10
# 4   4    10005 2016-02-27           WU      I27.0
# 5   5    10006 2016-03-01           WU      I50.9
#
#                         Pri_dx_name Sec_dx_icd  \
# 0        Heart failure, unspecified        I10
# 1        Heart failure, unspecified        I10
# 2      Angina pectoris, unspecified      E11.9
# 3  Essential (primary) hypertension
# 4    Primary pulmonary hypertension      I50.9
# 5        Heart failure, unspecified      E11.9
#
#                                       Sec_dx_name
# 0                Essential (primary) hypertension
# 1                Essential (primary) hypertension
# 2  Type 2 diabetes mellitus without complications
# 3
# 4                      Heart failure, unspecified
# ...

# %%
VISIT['Heart_failure'] = ((VISIT['Pri_dx_icd'] == 'I50.9') | (VISIT['Sec_dx_icd'] == 'I50.9'))
#Add a column of Heart_failure in the table "VISIT".
#The positive result(True) in each cell of Heart_failure is confirmed when Pri_dx_icd or Sec_dx_icd equal I50.9

# %%
VISIT
# Out:
#   Pid Visit_id Visit_date Attending_md Pri_dx_icd  \
# 0   1    10001 2016-01-09      JOHNSON      I50.9
# 1   1    10002 2016-01-17      JOHNSON      I50.9
# 2   2    10003 2016-01-15           WU      I20.9
# 3   3    10004 2016-02-01      JOHNSON        I10
# 4   4    10005 2016-02-27           WU      I27.0
# 5   5    10006 2016-03-01           WU      I50.9
#
#                         Pri_dx_name Sec_dx_icd  \
# 0        Heart failure, unspecified        I10
# 1        Heart failure, unspecified        I10
# 2      Angina pectoris, unspecified      E11.9
# 3  Essential (primary) hypertension
# 4    Primary pulmonary hypertension      I50.9
# 5        Heart failure, unspecified      E11.9
#
#                                       Sec_dx_name  Heart_failure
# 0                Essential (primary) hypertension           True
# 1                Essential (primary) hypertension           True
# 2  Type 2 diabetes mellitus without complications          False
# ...

# %%
VISIT['Heart_failure'] = ((VISIT['Pri_dx_icd'] == 'I50.9') | (VISIT['Sec_dx_icd'] == 'I50.9')).astype(int)
#.astype(int) is to convert the result to Boolean values
#Boolean values are True and False;when we add as type.(int) we convert Boolean into integer and Python automatically converts True to 1 and False to 0

# %%
VISIT
# Out:
#   Pid Visit_id Visit_date Attending_md Pri_dx_icd  \
# 0   1    10001 2016-01-09      JOHNSON      I50.9
# 1   1    10002 2016-01-17      JOHNSON      I50.9
# 2   2    10003 2016-01-15           WU      I20.9
# 3   3    10004 2016-02-01      JOHNSON        I10
# 4   4    10005 2016-02-27           WU      I27.0
# 5   5    10006 2016-03-01           WU      I50.9
#
#                         Pri_dx_name Sec_dx_icd  \
# 0        Heart failure, unspecified        I10
# 1        Heart failure, unspecified        I10
# 2      Angina pectoris, unspecified      E11.9
# 3  Essential (primary) hypertension
# 4    Primary pulmonary hypertension      I50.9
# 5        Heart failure, unspecified      E11.9
#
#                                       Sec_dx_name  Heart_failure
# 0                Essential (primary) hypertension              1
# 1                Essential (primary) hypertension              1
# 2  Type 2 diabetes mellitus without complications              0
# ...

# %%
MEDICATIONS.groupby('Pid')['Rx_name'].count()
#By the key"Pid" in the table "MEDICATIONS" to group, and count the number of Rx_name
#Same idea as "GROUP BY" in SQL
# Out:
# Pid
# 1    2
# 2    4
# 3    1
# 4    3
# 5    3
# Name: Rx_name, dtype: int64

# %%
test_df = MEDICATIONS.groupby('Pid')['Rx_name'].nunique().sort_values(ascending=False)
#Group by Pid
#Calculate Rx_name
#Count without repeating items
#Order by descending values

# %%
test_df = pd.DataFrame(test_df)

# %%
test_df[test_df['Rx_name'] > 2]
#Show the items which numbers of different Rx_name are greater than 2.
# Out:
#      Rx_name
# Pid
# 2          4
# 5          3
# 4          3

# %%
def temp_f_to_c(temp_f):
  temp_c = (temp_f - 32) * 5/9
  return temp_c

# %%
temp_f_to_c(49)
# Out:
# 9.444444444444445

# %%
temp_list = [49,39,75,0,87]

# %%
for temp in temp_list:
  print(temp_f_to_c(temp))
  #Loops:for anything in target
# Out:
# 9.444444444444445
# 3.888888888888889
# 23.88888888888889
# -17.77777777777778
# 30.555555555555557
